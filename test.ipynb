# %%
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
nn = load_model('heart.keras')
df = pd.read_csv('heart.csv')
df
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# ...

# %%
df['RestingECG'].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
# Use a sample input with the expected number of features (16)
# Columns: Age, Sex, RestingBP, Cholesterol, FastingBS, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, ChestPainType_ASY, ChestPainType_ATA, ChestPainType_NAP, ChestPainType_TA, RestingECG_LVH, RestingECG_Normal, RestingECG_ST
sample_input = np.array([[40, 1, 140, 289, 0, 172, 0, 0.0, 2, 0, 0, 0, 1, 0, 0, 0]]).astype(float)
display(sample_input)
# print(nn.predict(sample_input))

if nn.predict(sample_input)[0][0] > 0:
    print('Have Heart Disease')
else: 
    print("Dont have heart disease")
# Out:
# array([[ 40.,   1., 140., 289.,   0., 172.,   0.,   0.,   2.,   0.,   0.,
#           0.,   1.,   0.,   0.,   0.]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Have Heart Disease

# %%
cleanData = pd.read_csv('cleanedDataFrame.csv')
sample_input = cleanData.sample()
sample_input.drop(['HeartDisease'], axis=1, inplace=True)
display(sample_input)
if nn.predict(sample_input)[0][0] > 0:
    print('Have Heart Disease')
else: 
    print("Dont have heart disease")
# Out:
#         Age       Sex  RestingBP  Cholesterol  FastingBS     MaxHR  \
# 600  0.3701  0.515952  -0.129513      0.07501  -0.551341 -1.603734
#
#      ExerciseAngina   Oldpeak  ST_Slope  ChestPainType_ASY  ChestPainType_ATA  \
# 600       -1.214246  0.105664 -0.596078          -0.481887          -0.532838
#
#      ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 600          -0.229679         -0.507478       -1.228087           2.038947
#
#      RestingECG_ST
# 600            0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Have Heart Disease

# %%
print(df["ExerciseAngina"].value_counts())
print(df["ExerciseAngina"].unique())
# Out:
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64
# <ArrowStringArray>
# ['N', 'Y']
# Length: 2, dtype: str

# %%
print(df["ST_Slope"].unique())
# Out:
# <ArrowStringArray>
# ['Up', 'Flat', 'Down']
# Length: 3, dtype: str

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(X.columns.tolist())
#       2 print(sampleDF.columns.tolist())
#
# NameError: name 'X' is not defined
